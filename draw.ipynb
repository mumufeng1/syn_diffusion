# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# draw FID curve
epochs = [25*(i+1) for i in range(5)]

dif_fid = [[1.3710601719197708,
            1.3624641833810887,
            1.343123209169054,
            1.362464183381088,
            1.3624641833810887],
           [0.14667508270770965,
            0.1371422848951489,
            0.15874560439821428,
            0.13899011367347583,
            0.13647543427678344],
           [0.14602551439108105,
            0.6514319866414572,
            0.14433246545097428,
            0.1128892669418097,
            0.15756700881187558]]

gan_fid = [[1.5214899713467043,
            1.4226361031518624,
            1.4914040114613178,
            1.663323782234957,
            3.1053008595988536],
           [0.34555065855256617,
            0.21908250867339132,
            0.21942269444060641,
            0.21668955356713365,
            0.22539711609990742],
           [0.9759876493436314,
            0.9803591615712742,
            1.2300523329491055,
            1.2796727514867205,
            1.6413831349875943]]

# plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['lines.color'] = 'black'
plt.rcParams['savefig.facecolor'] = 'white'

line_style = ['-', '--']
dataset_name = ['a', 'b', 'c']
dataset_mark = ['Wang\'s', 'Johns\'s', 'Lubliner\'s']
plt.rcParams["figure.figsize"] = (10, 3.5)
plt.figure(facecolor='white')
y_max = [3, 0.5 ,1.6]

for i in range(3):
    plt.subplot(1, 3, i+1)
    ax = plt.gca()

    plt.plot(epochs, dif_fid[i], label='diffusion', color='#7F98AB',
             marker='o',
             # linestyle=line_style[i]
             )
    plt.plot(epochs, gan_fid[i], label='WGAN', color='#B96666',
             marker='o',
             # linestyle=line_style[i]
             )
    # plt.title("FID")
    # plt.ylim((0, 1))
    ax.axhline(linewidth=2, color='black')
    ax.axvline(linewidth=2, color='black')
    ax.set_facecolor('white')
    plt.minorticks_on()
    plt.xticks([i * 25 for i in range(6)])
    plt.rc_context({"xtick.color": "black", "ytick.color": "black"})


    plt.ylim(ymin=0)
    plt.xlim(xmin=0,  xmax=130)
    if i == 1:
        plt.ylim(ymax=0.55)
    plt.xlabel('Epochs')
    plt.ylabel('FID')
    # ax.set_title('(' + dataset_name[i] + ')', y=-0.3, fontsize=14)
    # plt.suptitle('(' + dataset_name[i] + ')', fontsize=14)
    plt.title(dataset_mark[i])
    plt.legend(loc = "upper left", facecolor='white')
    plt.text(62.5, -y_max[i]/4, '(' + dataset_name[i] + ')', fontsize=14)

plt.savefig("fig/fid.pdf", bbox_inches='tight')
plt.show()

# %%
# draw r2 of k-mer freq curve
epochs = [10*(i+1) for i in range(13)]

dif_k_mer_freq = [[[0.889539, 0.822634, 0.839405, 0.91148, 0.95246, 0.934719, 0.905227, 0.974627, 0.924756, 0.944026,
                   0.899407, 0.813667, 0.903361],
                   [0.910443, 0.873124, 0.879536, 0.924231, 0.926303, 0.941827, 0.925109, 0.945215, 0.942869, 0.945411, 0.925367, 0.8667, 0.914193],
                   [0.904405, 0.884202, 0.880374, 0.920813, 0.908454, 0.938231, 0.923521, 0.935282, 0.939641, 0.938464, 0.926268, 0.883234, 0.923148],
                   [0.869139, 0.866594, 0.855885, 0.897343, 0.881752, 0.915122, 0.898544, 0.912825, 0.916765, 0.916909, 0.907206, 0.874628, 0.906153],
                   [0.799037, 0.802298, 0.785148, 0.835518, 0.824595, 0.855387, 0.836428, 0.848659, 0.8543, 0.859889, 0.853114, 0.82364, 0.849171]],
                   [-0.020053, 0.382086, 0.515287, 0.724337, 0.777403, 0.927164, 0.874811, 0.921202, 0.960606, 0.925002, 0.938252, 0.965427, 0.939711],
                   [-0.009512, 0.276324, 0.448473, 0.661548, 0.713051, 0.914674, 0.852649, 0.900589, 0.937139, 0.891579, 0.916336, 0.947613, 0.905707]],
                  [[0.239256, 0.782807, 0.912937, 0.694901, 0.792683, 0.986466, 0.80961, 0.967621, 0.871751, 0.81072, 0.992701, 0.946134, 0.871106],
                   [0.272702, 0.660007, 0.828377, 0.624681, 0.771917, 0.977484, 0.79029, 0.959183, 0.857758, 0.805265, 0.984369, 0.941158, 0.84344],
                   [0.2633, 0.534539, 0.728846, 0.571649, 0.722773, 0.950568, 0.770256, 0.932749, 0.835491, 0.794203, 0.962288, 0.924453, 0.812886],
                   [0.224182, 0.377596, 0.644436, 0.507053, 0.640009, 0.894669, 0.728317, 0.882007, 0.791131, 0.758034, 0.916494, 0.880178, 0.761817],
                   [0.170783, 0.252617, 0.54831, 0.41345, 0.530442, 0.799623, 0.664394, 0.789842, 0.715521, 0.692337, 0.839958, 0.801856, 0.68863]]]

line_style = ['-', '--', '-.', ':', (0, (1, 5))]
dataset_name = ['a', 'b', 'c']
dataset_mark = ['Wang\'s', 'Johns\'s', 'Lubliner\'s']

# fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 4))
plt.rcParams["figure.figsize"] = (10, 3.5)
plt.figure(facecolor='white')
# 调整子图之间的间隔大小
plt.subplots_adjust(wspace=0.3)
for i in range(3):
    plt.subplot(1, 3, i+1)
    ax = plt.gca()
    for j in range(5):
        plt.plot(epochs, pow(np.array(dif_k_mer_freq[i][j]), 2), label='diffusion-{}-mer'.format(j+2), color='#7F98AB',
                 # marker='o',
                 linestyle=line_style[j]
                 )
        plt.plot(epochs, pow(np.array(gan_k_mer_freq[i][j]), 2), label='WGAN-{}-mer'.format(j+2), color='#B96666',
                 # marker='o',
                 linestyle=line_style[j]
                 )
    # plt.title("FID")
    # plt.ylim((0, 1))
    ax.axhline(linewidth=2, color='black')
    ax.axvline(linewidth=2, color='black')
    ax.set_facecolor('white')
    plt.minorticks_on()
    plt.xticks([i * 25 for i in range(6)])
    plt.rc_context({"xtick.color": "black", "ytick.color": "black"})
    plt.ylim(ymin=0)
    plt.ylim(ymax=1)
    plt.xlim(xmin=0,  xmax=130)
    # if i == 1:
    #     plt.ylim(ymax=0.55)
    plt.xlabel('Epochs')
    plt.ylabel('R2 of k-mer Frequency')
    ax.set_title('(' + dataset_name[i] + ')', y=-0.3, fontsize=14)
    plt.title(dataset_mark[i])
    plt.text(62.5, -0.25, '(' + dataset_name[i] + ')', fontsize=14)

    # plt.legend(loc = "upper left")
plt.legend(loc="upper center", bbox_to_anchor=(-0.88, 1.3), ncol=5, facecolor='white')
plt.savefig("fig/k_mer_freq_curve.pdf", bbox_inches='tight')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 # 读取JSON文件
#       4 file_path = 'gan/res/promoter_3/dis_loss.json'
# ----> 6 with open(file_path, 'r') as file:
#       7     json_content = json.load(file)
#       9 # 输出解析后的列表
#
# File D:\software\Anaconda\envs\torch\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gan/res/promoter_3/dis_loss.json'
